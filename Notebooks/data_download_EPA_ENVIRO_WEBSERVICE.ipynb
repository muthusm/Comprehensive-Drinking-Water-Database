# %%
import os
import glob
import urllib
import pandas as pd

# %% [markdown]
# The Envirofacts database is maintained by the US Environmental Protection Agency (EPA).
# Envirofacts allows you to retrieve environmental information from EPA databases on air, chemicals, facility information, hazardous waste, risk management plans, Superfund, toxic releases, and water permits. We are focussing on Safe Drinking Water Information System. The Safe Drinking Water Information System (SDWIS) contains information about public water systems and their violations of EPA's drinking water regulations. These statutes and accompanying regulations establish maximum contaminant levels, treatment techniques, and monitoring and reporting requirements to ensure that water provided to customers is safe for human consumption.
#
# https://enviro.epa.gov
#
# https://www.epa.gov/enviro/web-services

# %%
tables = ['ENFORCEMENT_ACTION',
          'GEOGRAPHIC_AREA',
          'LCR_SAMPLE_RESULT',
          'LCR_SAMPLE',
          'SERVICE_AREA',
          'TREATMENT',
          'WATER_SYSTEM',
          'WATER_SYSTEM_FACILITY',
          'VIOLATION',
          'VIOLATION_ENF_ASSOC']

# %%
import requests
table_total_rows = {}
for table in tables:
    data_url = 'https://data.epa.gov/efservice/'+table+'/COUNT/JSON'
    response = requests.get(data_url)
    table_total_rows[table] = int(response.json()[0]['TOTALQUERYRESULTS'])

# %%
print('Total number of rows in each table (result got from webservice)')
print('-' * 63)
for table in table_total_rows:
    print(table, ':', table_total_rows[table])
# Out:
# Total number of rows in each table (result got from webservice)
# ---------------------------------------------------------------
# ENFORCEMENT_ACTION :	 2108953
# GEOGRAPHIC_AREA :	 406044
# LCR_SAMPLE_RESULT :	 225184
# LCR_SAMPLE :	 224842
# SERVICE_AREA :	 414314
# TREATMENT :	 428353
# WATER_SYSTEM :	 426547
# WATER_SYSTEM_FACILITY :	 1456300
# VIOLATION :	 2058022
# VIOLATION_ENF_ASSOC :	 13788197

# %%
import os
for table_name in table_total_rows:
    print(table_name)
    data_dir = 'new_data/'+ table_name.lower() +'/' 
    os.makedirs(data_dir,exist_ok=True)    
    total_end_index = table_total_rows[table_name] // 100000
    print('total_end_index', total_end_index)
    for start_index in range(0, total_end_index):
        start_index = start_index * 100000
        print(table_name, start_index, (start_index+100000))
        data_url = 'https://data.epa.gov/efservice/'+ table_name +'/ROWS/'+str(start_index)+':'+str(start_index+100000)+'/EXCEL'
        urllib.request.urlretrieve(data_url, data_dir + table_name + '_' +str(start_index)+'.csv')
        print('completed')

    start_index = total_end_index * 100000
    end_index = table_total_rows[table_name]
    print(table_name, start_index, end_index)
    data_url = 'https://data.epa.gov/efservice/'+ table_name +'/ROWS/'+str(start_index)+':'+str(end_index-1)+'/EXCEL'
    urllib.request.urlretrieve(data_url, data_dir + table_name + '_' +str(start_index)+'.csv')
    print(data_dir + table_name + '_' +str(start_index)+'.csv')
    print('completed')
# Out:
# ENFORCEMENT_ACTION
# total_end_index 21
# ENFORCEMENT_ACTION 0 100000
# completed
# ENFORCEMENT_ACTION 100000 200000
# completed
# ENFORCEMENT_ACTION 200000 300000
# completed
# ENFORCEMENT_ACTION 300000 400000
# completed
# ENFORCEMENT_ACTION 400000 500000
# completed
# ENFORCEMENT_ACTION 500000 600000
# completed
# ENFORCEMENT_ACTION 600000 700000
# completed
# ENFORCEMENT_ACTION 700000 800000
# completed
# ENFORCEMENT_ACTION 800000 900000
# completed
# ENFORCEMENT_ACTION 900000 1000000
# completed
# ENFORCEMENT_ACTION 1000000 1100000
# completed
# ENFORCEMENT_ACTION 1100000 1200000
# completed
# ENFORCEMENT_ACTION 1200000 1300000
# completed
# ENFORCEMENT_ACTION 1300000 1400000
# completed
# ENFORCEMENT_ACTION 1400000 1500000
# completed
# ENFORCEMENT_ACTION 1500000 1600000
# completed
# ENFORCEMENT_ACTION 1600000 1700000
# completed
# ENFORCEMENT_ACTION 1700000 1800000
# completed
# ENFORCEMENT_ACTION 1800000 1900000
# completed
# ENFORCEMENT_ACTION 1900000 2000000
# completed
# ENFORCEMENT_ACTION 2000000 2100000
# completed
# ENFORCEMENT_ACTION 2100000 2108953
# new_data/enforcement_action/ENFORCEMENT_ACTION_2100000.csv
# completed
# GEOGRAPHIC_AREA
# total_end_index 4
# GEOGRAPHIC_AREA 0 100000
# completed
# GEOGRAPHIC_AREA 100000 200000
# completed
# GEOGRAPHIC_AREA 200000 300000
# completed
# GEOGRAPHIC_AREA 300000 400000
# completed
# GEOGRAPHIC_AREA 400000 406044
# new_data/geographic_area/GEOGRAPHIC_AREA_400000.csv
# completed
# LCR_SAMPLE_RESULT
# total_end_index 2
# LCR_SAMPLE_RESULT 0 100000
# completed
# LCR_SAMPLE_RESULT 100000 200000
# completed
# LCR_SAMPLE_RESULT 200000 225184
# new_data/lcr_sample_result/LCR_SAMPLE_RESULT_200000.csv
# completed
# LCR_SAMPLE
# total_end_index 2
# LCR_SAMPLE 0 100000
# completed
# LCR_SAMPLE 100000 200000
# completed
# LCR_SAMPLE 200000 224842
# new_data/lcr_sample/LCR_SAMPLE_200000.csv
# completed
# SERVICE_AREA
# total_end_index 4
# SERVICE_AREA 0 100000
# completed
# SERVICE_AREA 100000 200000
# completed
# SERVICE_AREA 200000 300000
# completed
# SERVICE_AREA 300000 400000
# completed
# SERVICE_AREA 400000 414314
# new_data/service_area/SERVICE_AREA_400000.csv
# completed
# TREATMENT
# total_end_index 4
# TREATMENT 0 100000
# completed
# TREATMENT 100000 200000
# completed
# TREATMENT 200000 300000
# completed
# TREATMENT 300000 400000
# completed
# TREATMENT 400000 428353
# new_data/treatment/TREATMENT_400000.csv
# completed
# WATER_SYSTEM_FACILITY
# total_end_index 14
# WATER_SYSTEM_FACILITY 0 100000
# completed
# WATER_SYSTEM_FACILITY 100000 200000
# completed
# WATER_SYSTEM_FACILITY 200000 300000
# completed
# WATER_SYSTEM_FACILITY 300000 400000
# completed
# WATER_SYSTEM_FACILITY 400000 500000
# completed
# WATER_SYSTEM_FACILITY 500000 600000
# completed
# WATER_SYSTEM_FACILITY 600000 700000
# completed
# WATER_SYSTEM_FACILITY 700000 800000
# completed
# WATER_SYSTEM_FACILITY 800000 900000
# completed
# WATER_SYSTEM_FACILITY 900000 1000000
# completed
# WATER_SYSTEM_FACILITY 1000000 1100000
# completed
# WATER_SYSTEM_FACILITY 1100000 1200000
# completed
# WATER_SYSTEM_FACILITY 1200000 1300000
# completed
# WATER_SYSTEM_FACILITY 1300000 1400000
# completed
# WATER_SYSTEM_FACILITY 1400000 1456300
# new_data/water_system_facility/WATER_SYSTEM_FACILITY_1400000.csv
# completed
# VIOLATION_ENF_ASSOC
# total_end_index 137
# VIOLATION_ENF_ASSOC 0 100000
# completed
# VIOLATION_ENF_ASSOC 100000 200000
# completed
# VIOLATION_ENF_ASSOC 200000 300000
# completed
# VIOLATION_ENF_ASSOC 300000 400000
# completed
# VIOLATION_ENF_ASSOC 400000 500000
# completed
# VIOLATION_ENF_ASSOC 500000 600000
# completed
# VIOLATION_ENF_ASSOC 600000 700000
# completed
# VIOLATION_ENF_ASSOC 700000 800000
# completed
# VIOLATION_ENF_ASSOC 800000 900000
# completed
# VIOLATION_ENF_ASSOC 900000 1000000
# completed
# VIOLATION_ENF_ASSOC 1000000 1100000
# completed
# VIOLATION_ENF_ASSOC 1100000 1200000
# completed
# VIOLATION_ENF_ASSOC 1200000 1300000
# completed
# VIOLATION_ENF_ASSOC 1300000 1400000
# completed
# VIOLATION_ENF_ASSOC 1400000 1500000
# completed
# VIOLATION_ENF_ASSOC 1500000 1600000
# completed
# VIOLATION_ENF_ASSOC 1600000 1700000
# completed
# VIOLATION_ENF_ASSOC 1700000 1800000
# completed
# VIOLATION_ENF_ASSOC 1800000 1900000
# completed
# VIOLATION_ENF_ASSOC 1900000 2000000
# completed
# VIOLATION_ENF_ASSOC 2000000 2100000
# completed
# VIOLATION_ENF_ASSOC 2100000 2200000
# completed
# VIOLATION_ENF_ASSOC 2200000 2300000
# completed
# VIOLATION_ENF_ASSOC 2300000 2400000
# completed
# VIOLATION_ENF_ASSOC 2400000 2500000
# completed
# VIOLATION_ENF_ASSOC 2500000 2600000
# completed
# VIOLATION_ENF_ASSOC 2600000 2700000
# completed
# VIOLATION_ENF_ASSOC 2700000 2800000
# completed
# VIOLATION_ENF_ASSOC 2800000 2900000
# completed
# VIOLATION_ENF_ASSOC 2900000 3000000
# completed
# VIOLATION_ENF_ASSOC 3000000 3100000
# completed
# VIOLATION_ENF_ASSOC 3100000 3200000
# completed
# VIOLATION_ENF_ASSOC 3200000 3300000
# completed
# VIOLATION_ENF_ASSOC 3300000 3400000
# completed
# VIOLATION_ENF_ASSOC 3400000 3500000
# completed
# VIOLATION_ENF_ASSOC 3500000 3600000
# completed
# VIOLATION_ENF_ASSOC 3600000 3700000
# completed
# VIOLATION_ENF_ASSOC 3700000 3800000
# completed
# VIOLATION_ENF_ASSOC 3800000 3900000
# completed
# VIOLATION_ENF_ASSOC 3900000 4000000
# completed
# VIOLATION_ENF_ASSOC 4000000 4100000
# completed
# VIOLATION_ENF_ASSOC 4100000 4200000
# completed
# VIOLATION_ENF_ASSOC 4200000 4300000
# completed
# VIOLATION_ENF_ASSOC 4300000 4400000
# completed
# VIOLATION_ENF_ASSOC 4400000 4500000
# completed
# VIOLATION_ENF_ASSOC 4500000 4600000
# completed
# VIOLATION_ENF_ASSOC 4600000 4700000
# completed
# VIOLATION_ENF_ASSOC 4700000 4800000
# completed
# VIOLATION_ENF_ASSOC 4800000 4900000
# completed
# VIOLATION_ENF_ASSOC 4900000 5000000
# completed
# VIOLATION_ENF_ASSOC 5000000 5100000
# completed
# VIOLATION_ENF_ASSOC 5100000 5200000
# completed
# VIOLATION_ENF_ASSOC 5200000 5300000
# completed
# VIOLATION_ENF_ASSOC 5300000 5400000
# completed
# VIOLATION_ENF_ASSOC 5400000 5500000
# completed
# VIOLATION_ENF_ASSOC 5500000 5600000
# completed
# VIOLATION_ENF_ASSOC 5600000 5700000
# completed
# VIOLATION_ENF_ASSOC 5700000 5800000
# completed
# VIOLATION_ENF_ASSOC 5800000 5900000
# completed
# VIOLATION_ENF_ASSOC 5900000 6000000
# completed
# VIOLATION_ENF_ASSOC 6000000 6100000
# completed
# VIOLATION_ENF_ASSOC 6100000 6200000
# completed
# VIOLATION_ENF_ASSOC 6200000 6300000
# completed
# VIOLATION_ENF_ASSOC 6300000 6400000
# completed
# VIOLATION_ENF_ASSOC 6400000 6500000
# completed
# VIOLATION_ENF_ASSOC 6500000 6600000
# completed
# VIOLATION_ENF_ASSOC 6600000 6700000
# completed
# VIOLATION_ENF_ASSOC 6700000 6800000
# completed
# VIOLATION_ENF_ASSOC 6800000 6900000
# completed
# VIOLATION_ENF_ASSOC 6900000 7000000
# completed
# VIOLATION_ENF_ASSOC 7000000 7100000
# completed
# VIOLATION_ENF_ASSOC 7100000 7200000
# completed
# VIOLATION_ENF_ASSOC 7200000 7300000
# completed
# VIOLATION_ENF_ASSOC 7300000 7400000
# completed
# VIOLATION_ENF_ASSOC 7400000 7500000
# completed
# VIOLATION_ENF_ASSOC 7500000 7600000
# completed
# VIOLATION_ENF_ASSOC 7600000 7700000
# completed
# VIOLATION_ENF_ASSOC 7700000 7800000
# completed
# VIOLATION_ENF_ASSOC 7800000 7900000
# completed
# VIOLATION_ENF_ASSOC 7900000 8000000
# completed
# VIOLATION_ENF_ASSOC 8000000 8100000
# completed
# VIOLATION_ENF_ASSOC 8100000 8200000
# completed
# VIOLATION_ENF_ASSOC 8200000 8300000
# completed
# VIOLATION_ENF_ASSOC 8300000 8400000
# completed
# VIOLATION_ENF_ASSOC 8400000 8500000
# completed
# VIOLATION_ENF_ASSOC 8500000 8600000
# completed
# VIOLATION_ENF_ASSOC 8600000 8700000
# completed
# VIOLATION_ENF_ASSOC 8700000 8800000
# completed
# VIOLATION_ENF_ASSOC 8800000 8900000
# completed
# VIOLATION_ENF_ASSOC 8900000 9000000
# completed
# VIOLATION_ENF_ASSOC 9000000 9100000
# completed
# VIOLATION_ENF_ASSOC 9100000 9200000
# completed
# VIOLATION_ENF_ASSOC 9200000 9300000
# completed
# VIOLATION_ENF_ASSOC 9300000 9400000
# completed
# VIOLATION_ENF_ASSOC 9400000 9500000
# completed
# VIOLATION_ENF_ASSOC 9500000 9600000
# completed
# VIOLATION_ENF_ASSOC 9600000 9700000
# completed
# VIOLATION_ENF_ASSOC 9700000 9800000
# completed
# VIOLATION_ENF_ASSOC 9800000 9900000
# completed
# VIOLATION_ENF_ASSOC 9900000 10000000
# completed
# VIOLATION_ENF_ASSOC 10000000 10100000
# completed
# VIOLATION_ENF_ASSOC 10100000 10200000
# completed
# VIOLATION_ENF_ASSOC 10200000 10300000
# completed
# VIOLATION_ENF_ASSOC 10300000 10400000
# completed
# VIOLATION_ENF_ASSOC 10400000 10500000
# completed
# VIOLATION_ENF_ASSOC 10500000 10600000
# completed
# VIOLATION_ENF_ASSOC 10600000 10700000
# completed
# VIOLATION_ENF_ASSOC 10700000 10800000
# completed
# VIOLATION_ENF_ASSOC 10800000 10900000
# completed
# VIOLATION_ENF_ASSOC 10900000 11000000
# completed
# VIOLATION_ENF_ASSOC 11000000 11100000
# completed
# VIOLATION_ENF_ASSOC 11100000 11200000
# completed
# VIOLATION_ENF_ASSOC 11200000 11300000
# completed
# VIOLATION_ENF_ASSOC 11300000 11400000
# completed
# VIOLATION_ENF_ASSOC 11400000 11500000
# completed
# VIOLATION_ENF_ASSOC 11500000 11600000
# completed
# VIOLATION_ENF_ASSOC 11600000 11700000
# completed
# VIOLATION_ENF_ASSOC 11700000 11800000
# completed
# VIOLATION_ENF_ASSOC 11800000 11900000
# completed
# VIOLATION_ENF_ASSOC 11900000 12000000
# completed
# VIOLATION_ENF_ASSOC 12000000 12100000
# completed
# VIOLATION_ENF_ASSOC 12100000 12200000
# completed
# VIOLATION_ENF_ASSOC 12200000 12300000
# completed
# VIOLATION_ENF_ASSOC 12300000 12400000
# completed
# VIOLATION_ENF_ASSOC 12400000 12500000
# completed
# VIOLATION_ENF_ASSOC 12500000 12600000
# completed
# VIOLATION_ENF_ASSOC 12600000 12700000
# completed
# VIOLATION_ENF_ASSOC 12700000 12800000
# completed
# VIOLATION_ENF_ASSOC 12800000 12900000
# completed
# VIOLATION_ENF_ASSOC 12900000 13000000
# completed
# VIOLATION_ENF_ASSOC 13000000 13100000
# completed
# VIOLATION_ENF_ASSOC 13100000 13200000
# completed
# VIOLATION_ENF_ASSOC 13200000 13300000
# completed
# VIOLATION_ENF_ASSOC 13300000 13400000
# completed
# VIOLATION_ENF_ASSOC 13400000 13500000
# completed
# VIOLATION_ENF_ASSOC 13500000 13600000
# completed
# VIOLATION_ENF_ASSOC 13600000 13700000
# completed
# VIOLATION_ENF_ASSOC 13700000 13788197
# new_data/violation_enf_assoc/VIOLATION_ENF_ASSOC_13700000.csv
# completed

# %% [markdown]
# All the tables of SDWIS are downloaded

# %%
print('Following files are downloaded using webservice')
print('-' * 47)
for file in filter(lambda x: x.endswith('.csv'), os.listdir('../raw_data')):
    print(file)
# Out:
# Following files are downloaded using webservice
# -----------------------------------------------
# WATER_SYSTEM_COUNTY.csv
# WATER_SYSTEM_FACILITY.csv
# TREATMENT.csv
# water_system_summary_submission_2021_q4.csv
# GEOGRAPHIC_AREA.csv
# LCR_SAMPLE_RESULT.csv
# VIOLATION.csv
# ENFORCEMENT_ACTION.csv
# SERVICE_AREA.csv
# WATER_SYSTEM.csv
# LCR_SAMPLE.csv

# %%
directories=[d for d in os.listdir('../raw_data') if os.path.isdir('../raw_data/'+d) and d != '.ipynb_checkpoints']
directories
# Out:
# ['water_system',
#  'treatment',
#  'service_area',
#  'water_system_facility',
#  'enforcement_action',
#  'lcr_sample_result',
#  'violation',
#  'water_system_county',
#  'geographic_area',
#  'lcr_sample',
#  'violation_enf_assoc']

# %%
for table_dir in directories[:-1]:
    print(table_dir)
    all_files = glob.glob(os.path.join('../raw_data/' + table_dir, "*.csv"))
    df = pd.concat((pd.read_csv(f, dtype=str) for f in all_files), ignore_index=True)
    df.columns = [col.replace('SDWISDM_B.'+table_dir.upper()+'.', '') for col in df.columns]
    # print(df.columns)
    df.to_csv('../raw_data/' +table_dir.upper()+'.csv', index=False)
# Out:
# water_system
# treatment
# service_area
# water_system_facility
# enforcement_action
# lcr_sample_result
# violation
# water_system_county
# geographic_area
# lcr_sample

# %%
print('Following datasets are fetched using EPA ENVIRO WEBSERVICE')
print('-'*58)
for file in filter(lambda x: x.endswith('.csv'), os.listdir('../raw_data/')):
    print(file)
# Out:
# Following datasets are fetched using EPA ENVIRO WEBSERVICE
# ----------------------------------------------------------
# WATER_SYSTEM_COUNTY.csv
# WATER_SYSTEM_FACILITY.csv
# TREATMENT.csv
# water_system_summary_submission_2021_q4.csv
# GEOGRAPHIC_AREA.csv
# LCR_SAMPLE_RESULT.csv
# VIOLATION.csv
# ENFORCEMENT_ACTION.csv
# SERVICE_AREA.csv
# WATER_SYSTEM.csv
# LCR_SAMPLE.csv
